# %% [markdown]
# # Communities and Crimes Dataset

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import re
#for EDA
from ydata_profiling import ProfileReport

#for visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#for preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OrdinalEncoder, OneHotEncoder

#for model
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.naive_bayes import GaussianNB as nb
from sklearn.linear_model import LogisticRegression as lr
from sklearn.tree import DecisionTreeClassifier as dt 
from sklearn.svm import SVC as vc
from sklearn.ensemble import RandomForestClassifier as rcl
import sklearn.metrics as sm

# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# ### Importing data

# %%
Crime_data = pd.read_csv('data/communities.data')
Crime_data.head()
# Out:
#     8   ?    ?.1         Lakewoodcity  1  0.19  0.33  0.02   0.9  0.12  ...  \
# 0  53   ?      ?          Tukwilacity  1  0.00  0.16  0.12  0.74  0.45  ...
# 1  24   ?      ?         Aberdeentown  1  0.00  0.42  0.49  0.56  0.17  ...
# 2  34   5  81440  Willingborotownship  1  0.04  0.77  1.00  0.08  0.12  ...
# 3  42  95   6096    Bethlehemtownship  1  0.01  0.55  0.02  0.95  0.09  ...
# 4   6   ?      ?    SouthPasadenacity  1  0.02  0.28  0.06  0.54  1.00  ...
#
#    0.12.2  0.26.1  0.2.1  0.06.3  0.04.2  0.9.1  0.5.2  0.32.2  0.14.3  0.2.2
# 0    0.02    0.12   0.45       ?       ?      ?      ?     0.0       ?   0.67
# 1    0.01    0.21   0.02       ?       ?      ?      ?     0.0       ?   0.43
# 2    0.02    0.39   0.28       ?       ?      ?      ?     0.0       ?   0.12
# 3    0.04    0.09   0.02       ?       ?      ?      ?     0.0       ?   0.03
# 4    0.01    0.58   0.10       ?       ?      ?      ?     0.0       ?   0.14
#
# [5 rows x 128 columns]

# %% [markdown]
# As we can see, the data currently has no column name. We need to take them from other file called 'attributes.csv'.

# %%
col_names = pd.read_csv('data/attributes.csv', delim_whitespace=True)
col_names = col_names['attributes']
Crime_data = pd.read_csv('data/communities.data', names = col_names)
Crime_data.head()
# Out:
#    state county community        communityname  fold  population  \
# 0      8      ?         ?         Lakewoodcity     1        0.19
# 1     53      ?         ?          Tukwilacity     1        0.00
# 2     24      ?         ?         Aberdeentown     1        0.00
# 3     34      5     81440  Willingborotownship     1        0.04
# 4     42     95      6096    Bethlehemtownship     1        0.01
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# 0           0.33          0.02          0.90          0.12  ...      0.12
# 1           0.16          0.12          0.74          0.45  ...      0.02
# 2           0.42          0.49          0.56          0.17  ...      0.01
# 3           0.77          1.00          0.08          0.12  ...      0.02
# 4           0.55          0.02          0.95          0.09  ...      0.04
#
#    PopDens  PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# 0     0.26            0.20       0.06           0.04                  0.9
# 1     0.12            0.45          ?              ?                    ?
# 2     0.21            0.02          ?              ?                    ?
# 3     0.39            0.28          ?              ?                    ?
# 4     0.09            0.02          ?              ?                    ?
#
#    LemasGangUnitDeploy  LemasPctOfficDrugUn  PolicBudgPerPop  \
# 0                  0.5                 0.32             0.14
# 1                    ?                 0.00                ?
# 2                    ?                 0.00                ?
# 3                    ?                 0.00                ?
# 4                    ?                 0.00                ?
#
#    ViolentCrimesPerPop
# 0                 0.20
# 1                 0.67
# 2                 0.43
# 3                 0.12
# 4                 0.03
#
# [5 rows x 128 columns]

# %%
Crime_data.shape
# Out:
# (1994, 128)

# %%
Crime_data.describe().T
# Out:
#                       count       mean        std  min    25%    50%    75%  \
# state                1994.0  28.683551  16.397553  1.0  12.00  34.00  42.00
# fold                 1994.0   5.493982   2.873694  1.0   3.00   5.00   8.00
# population           1994.0   0.057593   0.126906  0.0   0.01   0.02   0.05
# householdsize        1994.0   0.463395   0.163717  0.0   0.35   0.44   0.54
# racepctblack         1994.0   0.179629   0.253442  0.0   0.02   0.06   0.23
# ...                     ...        ...        ...  ...    ...    ...    ...
# LandArea             1994.0   0.065231   0.109459  0.0   0.02   0.04   0.07
# PopDens              1994.0   0.232854   0.203092  0.0   0.10   0.17   0.28
# PctUsePubTrans       1994.0   0.161685   0.229055  0.0   0.02   0.07   0.19
# LemasPctOfficDrugUn  1994.0   0.094052   0.240328  0.0   0.00   0.00   0.00
# ViolentCrimesPerPop  1994.0   0.237979   0.232985  0.0   0.07   0.15   0.33
#
#                       max
# state                56.0
# fold                 10.0
# population            1.0
# householdsize         1.0
# racepctblack          1.0
# ...                   ...
# LandArea              1.0
# PopDens               1.0
# PctUsePubTrans        1.0
# LemasPctOfficDrugUn   1.0
# ViolentCrimesPerPop   1.0
#
# [102 rows x 8 columns]

# %%
Crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Columns: 128 entries, state to ViolentCrimesPerPop
# dtypes: float64(100), int64(2), object(26)
# memory usage: 1.9+ MB

# %%
Crime_data.duplicated().sum()
# Out:
# 0

# %%
Crime_data.isna().sum()
# Out:
# state                  0
# county                 0
# community              0
# communityname          0
# fold                   0
#                       ..
# LemasPctPolicOnPatr    0
# LemasGangUnitDeploy    0
# LemasPctOfficDrugUn    0
# PolicBudgPerPop        0
# ViolentCrimesPerPop    0
# Length: 128, dtype: int64

# %% [markdown]
# It can be observed that there are no columns containing NaN values. However, this does not prove that the dataset is free from data missings, and it is very possible that the dataset uses some specical characters to represent missing values. We will attempt to explore this by extracting unique values from a categorical column.

# %%
Crime_data['PolicCars'].unique()
# Out:
# array(['0.06', '?', '0.09', '1', '0.04', '0.05', '0.03', '0.41', '0.07',
#        '0.25', '0', '0.02', '0.18', '0.21', '0.1', '0.01', '0.22', '0.11',
#        '0.55', '0.08', '0.47', '0.16', '0.29', '0.14', '0.43', '0.15',
#        '0.28', '0.2', '0.62', '0.36', '0.37', '0.67', '0.12', '0.27',
#        '0.3', '0.58', '0.35', '0.71', '0.23', '0.17', '0.26', '0.82',
#        '0.51', '0.92', '0.24', '0.13', '0.32', '0.19', '0.49', '0.38',
#        '0.61', '0.65', '0.73', '0.89', '0.72', '0.64', '0.31', '0.68',
#        '0.4', '0.44', '0.98', '0.53', '0.69', '0.45'], dtype=object)

# %% [markdown]
# From the above result, we see that there is an unique value '?' in the dataset and it definitely represents a missing value. So we will replace all of '?' with NaN values for the ease of further analysis.

# %%
print('Before:')
print(Crime_data.isna().sum())
Crime_data = Crime_data.replace(to_replace='?', value=np.nan)
print('After:')
Crime_data.isna().sum()
# Out:
# Before:
# state                  0
# county                 0
# community              0
# communityname          0
# fold                   0
#                       ..
# LemasPctPolicOnPatr    0
# LemasGangUnitDeploy    0
# LemasPctOfficDrugUn    0
# PolicBudgPerPop        0
# ViolentCrimesPerPop    0
# Length: 128, dtype: int64
# After:
# state                     0
# county                 1174
# community              1177
# communityname             0
# fold                      0
#                        ...
# LemasPctPolicOnPatr    1675
# LemasGangUnitDeploy    1675
# LemasPctOfficDrugUn       0
# PolicBudgPerPop        1675
# ViolentCrimesPerPop       0
# Length: 128, dtype: int64

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# 1. Categorical Attributes

# %%
categorical_columns = ['state', 'county', 'community', 'communityname']

# %% [markdown]
# 2. Numerical Attributes

# %%
numerical_columns = list(set(Crime_data.columns) - set(categorical_columns))
numerical_columns.remove('ViolentCrimesPerPop')
numerical_columns
# Out:
# ['PctPopUnderPov',
#  'OwnOccLowQuart',
#  'PctVacantBoarded',
#  'HousVacant',
#  'PctPolicMinor',
#  'NumInShelters',
#  'LemasTotReqPerPop',
#  'PctYoungKids2Par',
#  'PctSameCity85',
#  'PctOccupManu',
#  'PctImmigRec5',
#  'PctIlleg',
#  'racePctAsian',
#  'PctNotSpeakEnglWell',
#  'pctWPubAsst',
#  'PctLess9thGrade',
#  'MedRent',
#  'agePct12t21',
#  'pctWFarmSelf',
#  'LemasGangUnitDeploy',
#  'PersPerOccupHous',
#  'PctUsePubTrans',
#  'pctWWage',
#  'population',
#  'PctRecentImmig',
#  'pctWRetire',
#  'MalePctDivorce',
#  'PolicBudgPerPop',
#  'NumUnderPov',
#  'PctPolicAsian',
#  'PctNotHSGrad',
#  'PctTeen2Par',
#  'PctPolicHisp',
#  'whitePerCap',
#  'PctRecImmig10',
#  'numbUrban',
#  'OtherPerCap',
#  'perCapInc',
#  'PctKids2Par',
#  'fold',
#  'pctUrban',
#  'agePct12t29',
#  'PctHousNoPhone',
#  'MedYrHousBuilt',
#  'householdsize',
#  'PctWorkMomYoungKids',
#  'PctHousLess3BR',
#  'OwnOccHiQuart',
#  'PctOccupMgmtProf',
#  'agePct65up',
#  'NumKindsDrugsSeiz',
#  'racePctHisp',
#  'racepctblack',
#  'PctForeignBorn',
#  'medIncome',
#  'PctImmigRec8',
#  'NumImmig',
#  'PersPerOwnOccHous',
#  'PctSameHouse85',
#  'PctPersOwnOccup',
#  'PctEmplProfServ',
#  'LemasSwFTPerPop',
#  'PctFam2Par',
#  'PctLargHouseOccup',
#  'AsianPerCap',
#  'PctHousOccup',
#  'NumIlleg',
#  'PctVacMore6Mos',
#  'MalePctNevMarr',
#  'RentLowQ',
#  'pctWSocSec',
#  'PctPolicBlack',
#  'LemasTotalReq',
#  'LemasSwFTFieldPerPop',
#  'PctSameState85',
#  'PolicOperBudg',
#  'agePct16t24',
#  'PctUnemployed',
#  'LemasSwFTFieldOps',
#  'PopDens',
#  'PersPerFam',
#  'PctPersDenseHous',
#  'PctEmplManu',
#  'TotalPctDiv',
#  'RentHighQ',
#  'medFamInc',
#  'PctPolicWhite',
#  'PolicPerPop',
#  'MedNumBR',
#  'PctRecImmig5',
#  'PersPerRentOccHous',
#  'PctImmigRec10',
#  'PctRecImmig8',
#  'pctWInvInc',
#  'PctWorkMom',
#  'PctBSorMore',
#  'indianPerCap',
#  'OwnOccMedVal',
#  'PolicCars',
#  'blackPerCap',
#  'FemalePctDiv',
#  'racePctWhite',
#  'MedRentPctHousInc',
#  'MedOwnCostPctInc',
#  'HispPerCap',
#  'LemasPctPolicOnPatr',
#  'RentMedian',
#  'OfficAssgnDrugUnits',
#  'RacialMatchCommPol',
#  'LemasPctOfficDrugUn',
#  'NumStreet',
#  'PolicReqPerOffic',
#  'PctSpeakEnglOnly',
#  'PolicAveOTWorked',
#  'PctImmigRecent',
#  'PctHousOwnOcc',
#  'PctWOFullPlumb',
#  'PctLargHouseFam',
#  'PctEmploy',
#  'LandArea',
#  'PctBornSameState',
#  'MedOwnCostPctIncNoMtg',
#  'LemasSwornFT']

# %% [markdown]
# ## Data Exploration and Visualization

# %%
profile = ProfileReport(Crime_data, title = "Pandas Profiling Report for Communities and Crime dataset")
profile.to_file(output_file="Crime_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\Storm\Desktop\Python for ML\Final Project\Datasets-Analysis\Communities and Crime dataset\Communities-Crime-Dataset-Analysis.ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Storm/Desktop/Python%20for%20ML/Final%20Project/Datasets-Analysis/Communities%20and%20Crime%20dataset/Communities-Crime-Dataset-Analysis.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> profile = ProfileReport(Crime_data, title = "Pandas Profiling Report for Communities and Crime dataset")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Storm/Desktop/Python%20for%20ML/Final%20Project/Datasets-Analysis/Communities%20and%20Crime%20dataset/Communities-Crime-Dataset-Analysis.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> profile.to_file(output_file="Crime_profiling.html")
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:355, in ProfileReport.to_file(self, output_file, silent)
#     352         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     353     create_html_assets(self.config, output_file)
# --> 355 data = self.to_html()
#     357 if output_file.suffix != ".html":
#     358     suffix = output_file.suffix
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:470, in ProfileReport.to_html(self)
#     462 def to_html(self) -> str:
#     463     """Generate and return complete template as lengthy string
#     464         for using with frameworks.
#     465
#    (...)
#     468
#     469     """
# --> 470     return self.html
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:277, in ProfileReport.html(self)
#     274 @property
#     275 def html(self) -> str:
#     276     if self._html is None:
# --> 277         self._html = self._render_html()
#     278     return self._html
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:390, in ProfileReport._render_html(self)
#     385 report = self.report
#     387 with tqdm(
#     388     total=1, desc="Render HTML", disable=not self.config.progress_bar
#     389 ) as pbar:
# --> 390     html = HTMLReport(copy.deepcopy(report)).render(
#     391         nav=self.config.html.navbar_show,
#     392         offline=self.config.html.use_local_assets,
#     393         inline=self.config.html.inline,
#     394         assets_prefix=self.config.html.assets_prefix,
#     395         primary_color=self.config.html.style.primary_colors[0],
#     396         logo=self.config.html.style.logo,
#     397         theme=self.config.html.style.theme,
#     398         title=self.description_set.analysis.title,
#     399         date=self.description_set.analysis.date_start,
#     400         version=self.description_set.package["ydata_profiling_version"],
#     401     )
#     403     if self.config.html.minify_html:
#     404         from htmlmin.main import minify
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\ydata_profiling\report\presentation\flavours\html\root.py:12, in HTMLRoot.render(self, **kwargs)
#       6 def render(self, **kwargs) -> str:
#       7     nav_items = [
#       8         (section.name, section.anchor_id)
#       9         for section in self.content["body"].content["items"]
#      10     ]
# ---> 12     return templates.template("report.html").render(
#      13         **self.content, nav_items=nav_items, **kwargs
#      14     )
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\jinja2\environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File c:\Users\Storm\anaconda3\Lib\site-packages\jinja2\environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# MemoryError:

# %%
profile
